# %%
from sklearn.cluster import Ward, DBSCAN
from sklearn.neighbors import *
from sklearn import metrics, datasets, preprocessing, svm, cross_validation
from sklearn import decomposition

import pylab as pl
import pandas as pd

from prody import *
prody.confProDy(verbosity='error')

import numpy as np
import scipy
import os, sys
import csv
from pickle import dump, load
from itertools import groupby
from scipy.spatial.distance import cdist, pdist
from collections import defaultdict

import peptalk
# Out:
# @> ProDy is configured: verbosity='error'

# %%
dfeat, dtags = datasets.load_svmlight_file('boundMat.svmlight.txt', )
dfeat = dfeat.toarray()
X = preprocessing.scale(dfeat)

ddgs = np.array(loadtxt('boundRes.ddg.txt', skiprows=1, usecols=[3]))
y = ddgs>0

pdbs = loadtxt('boundMat.svmlight.txt', skiprows=1, usecols=[8], comments='$', dtype=np.str_)

# %%
SVM_PICKLE_FILENAME = 'svm.pkl'
if os.path.isfile(SVM_PICKLE_FILENAME):
    with open(SVM_PICKLE_FILENAME) as clf_file:
        classifier = load(clf_file)
else:
    classifier = svm.SVC(kernel='linear', probability=True, class_weight='auto').fit(X,y)

# %% [markdown]
# Cluster SVM results for all receptors in PeptiDB 1, and collect statistics in a CSV table about every cluster for subsequent analysis:

# %%
reload(peptalk)
# Out:
# <module 'peptalk' from 'peptalk.pyc'>

# %%
cluster_stats_fd = open('cluster-stats.csv', 'w')

#from StringIO import StringIO
#s = StringIO()
#csvwr = csv.writer(s, delimiter='\t')

csvwr = csv.writer(cluster_stats_fd,)# delimiter='\t')

csvwr.writerow(('PDBID', 'METHOD', 'RANK', 'SIZE', 'ENERGY_RECALL', 'ENERGY_RECALL_POSSIBLE', 'HOTSPOT_RECALL', 'HOTSPOT_PRECISION', 'BINDERS_RECALL', 'BINDERS_PRECISION', 'RESIDUES',))
for pdbid in set(pdbs):
    svm_result = peptalk.PeptalkResult(pdbid=pdbid, preds=classifier.predict(X[pdbs==pdbid])
        )
    
    ward_cl = svm_result.cluster_ward()
    dbscan_cl = svm_result.cluster_dbscan()
    for method, cluster_dict in (('DBSCAN', dbscan_cl), ('WARD', ward_cl),):
        for rank, resnums in cluster_dict.items():
            cluster_size = len(resnums)
            ddg_rcl, ddg_rcl_possible = svm_result.cluster_ddg_recall(resnums)
            hs_recl, hs_prec = svm_result.cluster_recall_precision(resnums, svm_result.ddg_resnums)
            bs_recl, bs_prec = svm_result.cluster_recall_precision(resnums, svm_result.binders_resnums)
            csvwr.writerow([
                            pdbid,
                            method,
                            rank,
                            cluster_size,
                            ddg_rcl,
                            ddg_rcl_possible,
                            hs_recl,
                            hs_prec,
                            bs_recl,
                            bs_prec,
                            ' '.join(map(str, resnums)),
                            ])
        #break

cluster_stats_fd.close()
# Out:
# /home/assaff/local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py:111: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   % n_components)
# /home/assaff/local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py:111: UserWarning: the number of connected components of the connectivity matrix is 3 > 1. Completing it to avoid stopping the tree early.
#   % n_components)
# 1X2R (2, 3)
# /home/assaff/local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py:111: UserWarning: the number of connected components of the connectivity matrix is 4 > 1. Completing it to avoid stopping the tree early.
#   % n_components)

# %%
df = pd.read_csv('cluster-stats.csv',)# index_col=['PDBID', 'METHOD','RANK'])
df.head(10)
# Out:
#   PDBID  METHOD  RANK  SIZE  ENERGY_RECALL  ENERGY_RECALL_POSSIBLE  HOTSPOT_RECALL  \
# 0  1D4T  DBSCAN     0    25       0.913386                1.000000        0.789474
# 1  1D4T  DBSCAN     1     3       0.000000                0.000000        0.000000
# 2  1D4T    WARD     0    13       0.566929                0.620690        0.473684
# 3  1D4T    WARD     1     7       0.039370                0.043103        0.105263
# 4  1D4T    WARD     2     6       0.307087                0.336207        0.210526
# 5  1D4T    WARD     3     5       0.000000                0.000000        0.000000
# 6  1D4T    WARD     4     3       0.000000                0.000000        0.000000
# 7  2O9V  DBSCAN     0    13       0.000000                0.000000        0.000000
# 8  2O9V  DBSCAN     1     4       0.392523                0.976744        0.166667
# 9  2O9V  DBSCAN     2     4       0.009346                0.023256        0.083333
#
#    HOTSPOT_PRECISION  BINDERS_RECALL  BINDERS_PRECISION  \
# 0           0.600000        0.857143           0.480000
# 1           0.000000        0.000000           0.000000
# 2           0.692308        0.428571           0.461538
# 3           0.285714        0.071429           0.142857
# 4           0.666667        0.357143           0.833333
# 5           0.000000        0.000000           0.000000
# 6           0.000000        0.000000           0.000000
# 7           0.000000        0.000000           0.000000
# 8           0.500000        0.428571           0.750000
# 9           0.250000        0.000000           0.000000
#
#                                             RESIDUES
# 0  10 17 32 35 36 37 38 49 50 51 52 53 54 55 66 6...
# 1                                           78 79 81
# 2             54 55 66 67 68 69 72 73 74 75 92 93 94
# 3                               10 32 35 36 37 38 39
# 4                                  17 49 50 51 52 53
# 5                                     58 62 78 79 81
# 6                                            3 5 101
# 7                2 3 5 45 47 48 49 51 52 62 64 65 67
# 8                                        36 37 40 41
# 9                                        18 19 20 21

# %%
db_clusters = df.ix[df.METHOD=='DBSCAN'].ix[:,'RANK':'SIZE']
size_pvt = db_clusters.pivot_table(rows='SIZE', cols=['RANK'], aggfunc=np.count_nonzero, fill_value=0)
size_pvt.plot(label='Rank', )#subplots=True, sharex=True, sharey=True, yticks=range(0,61,20), )
pl.ylabel('Frequency')
#savefig('interactive1.svg')

# %%
rcParams['text.usetex'] = True
top3_clusters = df.ix[(df.RANK<3) & (df.METHOD=='DBSCAN')]
method_pvt = top3_clusters.pivot_table(rows='PDBID', 
                cols=  [
                        #'METHOD',
                        'RANK',
                        ],
 
                values=['ENERGY_RECALL',
                        'HOTSPOT_RECALL',
                        'BINDERS_RECALL', 
                        'HOTSPOT_PRECISION', 
                        'BINDERS_PRECISION'], 
                        aggfunc=np.sum,
                        margins=True,
              )
recalls=method_pvt['ENERGY_RECALL']

display(method_pvt.ix[:,:4])

pl.hist([recalls[col] for col in recalls.columns], 
        bins=linspace(0, 1, num=6, endpoint=True), 
        label=recalls.columns.tolist(), 
        alpha=.8,
        )

pl.title('Distribution of $\Delta\Delta G$ recall for DBSCAN clustering')
pl.grid(axis='y')
pl.legend(loc='upper left')
pl.xlabel('Success rate ($ \Delta\Delta G $ recall)')
pl.ylabel('Frequency')
# Out:
#        ENERGY_RECALL
# RANK               0         1         2        All
# PDBID
# 1AWR        0.666667  0.000000  0.000000   0.666667
# 1CKA        0.854218  0.000000       NaN   0.854218
# 1CZY        0.376812  0.000000  0.000000   0.376812
# 1D4T        0.913386  0.000000       NaN   0.913386
# 1DDV        0.813953  0.000000       NaN   0.813953
# 1DKX        0.707317  0.000000       NaN   0.707317
# 1EG4        0.000000  0.000000  0.000000   0.000000
# 1ER8        0.250000  0.238636  0.056818   0.545455
# 1GYB        0.000000  0.000000  0.000000   0.000000
# 1HC9        0.979381       NaN       NaN   0.979381
# 1IHJ        0.250000  0.000000  0.000000   0.250000
# 1JD5        0.789474  0.000000  0.000000   0.789474
# 1JWG        0.828125  0.000000  0.000000   0.828125
# 1LVM        0.000000  0.000000  0.000000   0.000000
# 1MFG        0.717949  0.000000  0.000000   0.717949
# 1N7F        0.737705       NaN       NaN   0.737705
# 1NLN        0.350427  0.136752       NaN   0.487179
# 1NQ7        0.000000       NaN       NaN   0.000000
# 1NTV        0.766667  0.000000       NaN   0.766667
# 1NVR        0.000000  0.000000  0.000000   0.000000
# 1NX1        0.000000  0.788732       NaN   0.788732
# 1OAI        0.794872  0.000000  0.000000   0.794872
# 1QKZ        0.865546       NaN       NaN   0.865546
# 1RXZ        0.589286  0.000000  0.000000   0.589286
# 1SE0        0.000000  0.765625  0.000000   0.765625
# 1SFI        0.272727  0.376623  0.000000   0.649351
# 1SSH        0.845528  0.000000       NaN   0.845528
# 1T4F        0.777778       NaN       NaN   0.777778
# 1T7R        0.097826  0.228261       NaN   0.326087
# 1TP5        0.438596  0.000000  0.000000   0.438596
# 1TW6        0.929412  0.000000  0.000000   0.929412
# 1U00        0.680000  0.000000  0.000000   0.680000
# 1UJ0        0.819048  0.000000  0.000000   0.819048
# 1VZQ        0.000000  0.000000  0.000000   0.000000
# 1W9E        0.632353  0.000000  0.000000   0.632353
# 1X2R        0.131944       NaN       NaN   0.131944
# 1YMT        0.000000  0.000000       NaN   0.000000
# 1YWO        0.844828  0.000000  0.000000   0.844828
# 2A3I        0.171875  0.187500       NaN   0.359375
# 2AK5        0.941176  0.000000       NaN   0.941176
# 2B1Z        0.462687  0.000000  0.000000   0.462687
# 2B9H        0.000000  0.000000       NaN   0.000000
# 2BBA        0.477064  0.000000  0.000000   0.477064
# 2C3I        0.517857  0.000000  0.000000   0.517857
# 2CCH        0.472868  0.000000       NaN   0.472868
# 2D0N        0.902174  0.000000  0.000000   0.902174
# 2DS8        0.681818  0.045455       NaN   0.727273
# 2FMF        0.843750       NaN       NaN   0.843750
# 2FOJ        0.978022  0.000000       NaN   0.978022
# 2FVJ        0.000000  0.225352  0.000000   0.225352
# 2H9M        0.906250  0.000000       NaN   0.906250
# 2HO2        0.954023       NaN       NaN   0.954023
# 2HPL        0.861538  0.000000       NaN   0.861538
# 2J6F        0.938272  0.000000       NaN   0.938272
# 2JAM        0.000000  0.000000  0.000000   0.000000
# 2O02        0.313433  0.134328       NaN   0.447761
# 2O4J        0.747253       NaN       NaN   0.747253
# 2O9V        0.000000  0.009346  0.392523   0.401869
# 2P0W        0.234940  0.000000  0.000000   0.234940
# 2P1K        0.729730  0.000000       NaN   0.729730
# 2P1T        0.772727  0.000000  0.000000   0.772727
# 2P54        0.000000  0.238636  0.375000   0.613636
# 2PUY        0.600000       NaN       NaN   0.600000
# 2QOS        0.543478  0.137681  0.195652   0.876812
# 2R7G        0.491071  0.000000  0.000000   0.491071
# 2V3S        0.986111  0.000000       NaN   0.986111
# 2VJ0        0.026490  0.000000  0.000000   0.026490
# 2ZJD        0.104839  0.330645       NaN   0.435484
# 3BU3        0.408451  0.084507       NaN   0.492958
# 3BWA        0.461165  0.097087  0.184466   0.742718
# 3CVP        0.767442  0.000000  0.000000   0.767442
# 3D1E        0.520000  0.200000  0.000000   0.720000
# 3D9T        0.827160  0.000000  0.000000   0.827160
# All        37.365489  4.225168  1.204460  42.795117
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-a52b6af8f44e> in <module>()
#      22         bins=linspace(0, 1, num=6, endpoint=True),
#      23         label=recalls.columns.tolist(),
# ---> 24         alpha=.8,
#      25         )
#      26
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2655                       histtype=histtype, align=align, orientation=orientation,
#    2656                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2657                       stacked=stacked, **kwargs)
#    2658         draw_if_interactive()
#    2659     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8227             labels = list(label)
#    8228         else:
# -> 8229             raise ValueError('invalid label: must be string or sequence of strings')
#    8230
#    8231         if len(labels) < nx:
#
# ValueError: invalid label: must be string or sequence of strings

# %%
m=method_pvt.mean().unstack(1).unstack()
display(m)
display(m.idxmax(axis=1))
# Out:
# METHOD               DBSCAN                          WARD
# RANK                      0         1         2         0         1         2
# ENERGY_RECALL      0.513279  0.073800  0.035664  0.242250  0.161384  0.109115
# HOTSPOT_RECALL     0.405241  0.057297  0.022454  0.206439  0.121132  0.082395
# BINDERS_RECALL     0.539381  0.086586  0.037468  0.293412  0.157341  0.105543
# HOTSPOT_PRECISION  0.441110  0.201670  0.128205  0.360686  0.345767  0.266997
# BINDERS_PRECISION  0.504651  0.224452  0.127900  0.447650  0.349375  0.287467
# ENERGY_RECALL        (DBSCAN, 0)
# HOTSPOT_RECALL       (DBSCAN, 0)
# BINDERS_RECALL       (DBSCAN, 0)
# HOTSPOT_PRECISION    (DBSCAN, 0)
# BINDERS_PRECISION    (DBSCAN, 0)

# %%
method_pvt.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1AWR to 1HC9
# Data columns:
# (ENERGY_RECALL, DBSCAN, 0)        10  non-null values
# (ENERGY_RECALL, DBSCAN, 1)        9  non-null values
# (ENERGY_RECALL, DBSCAN, 2)        5  non-null values
# (ENERGY_RECALL, WARD, 0)          10  non-null values
# (ENERGY_RECALL, WARD, 1)          10  non-null values
# (ENERGY_RECALL, WARD, 2)          10  non-null values
# (HOTSPOT_RECALL, DBSCAN, 0)       10  non-null values
# (HOTSPOT_RECALL, DBSCAN, 1)       9  non-null values
# (HOTSPOT_RECALL, DBSCAN, 2)       5  non-null values
# (HOTSPOT_RECALL, WARD, 0)         10  non-null values
# (HOTSPOT_RECALL, WARD, 1)         10  non-null values
# (HOTSPOT_RECALL, WARD, 2)         10  non-null values
# (BINDERS_RECALL, DBSCAN, 0)       10  non-null values
# (BINDERS_RECALL, DBSCAN, 1)       9  non-null values
# (BINDERS_RECALL, DBSCAN, 2)       5  non-null values
# (BINDERS_RECALL, WARD, 0)         10  non-null values
# (BINDERS_RECALL, WARD, 1)         10  non-null values
# (BINDERS_RECALL, WARD, 2)         10  non-null values
# (HOTSPOT_PRECISION, DBSCAN, 0)    10  non-null values
# (HOTSPOT_PRECISION, DBSCAN, 1)    9  non-null values
# (HOTSPOT_PRECISION, DBSCAN, 2)    5  non-null values
# (HOTSPOT_PRECISION, WARD, 0)      10  non-null values
# (HOTSPOT_PRECISION, WARD, 1)      10  non-null values
# (HOTSPOT_PRECISION, WARD, 2)      10  non-null values
# (BINDERS_PRECISION, DBSCAN, 0)    10  non-null values
# (BINDERS_PRECISION, DBSCAN, 1)    9  non-null values
# (BINDERS_PRECISION, DBSCAN, 2)    5  non-null values
# (BINDERS_PRECISION, WARD, 0)      10  non-null values
# (BINDERS_PRECISION, WARD, 1)      10  non-null values
# (BINDERS_PRECISION, WARD, 2)      10  non-null values
# dtypes: float64(30)

# %% [markdown]
# ## Obsolete content

# %% [markdown]
# Visualizing clustering results with ProDy `showProtein`:

# %%
prody.SETTINGS['auto_show']=False
showProtein(prot, A='grey', B='magenta', label='prot', lw=3)
s = positives.copy()
s.setTitle('positive')
cluster_colors = {
        'CL0_': 'Red',
        'CL1_': 'DarkOrange',
        'CL2_': 'Coral',
        'CL3_': 'Yellow',
        'CL4_': 'White',
        'CL-1_': 'Green',
        }
   
s.ca.setResnames(['CL%s_' % str(label) for label in cluster_labels])
print cluster_colors
showProtein(s, hsize=10, label='positives', **cluster_colors)
pl.legend(loc='upper left')
pl.show()
# Out:
# {'CL1_': 'DarkOrange', 'CL0_': 'Red', 'CL4_': 'White', 'CL2_': 'Coral', 'CL3_': 'Yellow', 'CL-1_': 'Green'}

# %% [markdown]
# Produce a copy of `prot` with residues in `resnums` having beta numbers from `bfactors`:

# %%
def modifiedBetas(prot, resnums, bfactors):
    p = prot.copy()
    p.setBetas([0]*len(p))
    
    h = p.select('chain A and resnum %s' % ' '.join(map(str, resnums))).getHierView()
    for resnum, bfactor in zip(resnums, bfactors):
        res = h.getResidue('A', resnum)
        res.setBetas([bfactor]*len(res))
    
    return p

# %% [markdown]
# Measure the planarity of a set of coordinates using PCA:

# %%
def planarity(coords):
    pca = decomposition.PCA()
    pca.fit(coords)
    return 1-pca.explained_variance_ratio_[-1]

# %% [markdown]
# Score a set of clusters based on size and planarity:

# %%
def score_clusters(coords, cluster_labels):
    clusters = [coords[cluster_labels==i] for i in range(N_CLUSTERS)]
    planarities = np.array([planarity(cl_coords) for cl_coords in clusters])
    plana = planarities #preprocessing.scale(planarities)
    
    print plana
    sizes = np.array(map(len, clusters))
    print sizes
    
    scores = plana * sizes
    return scores
    #print len(coords), planarity,
    #return len(coords) * planarity
