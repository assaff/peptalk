# %%
from sklearn.cluster import Ward, DBSCAN
from sklearn.neighbors import *
from sklearn import metrics, datasets, preprocessing, svm, cross_validation
from sklearn import decomposition

import pylab as pl

import numpy as np
import scipy
from itertools import groupby
from scipy.spatial.distance import cdist, pdist
from collections import defaultdict

# %%
from prody import *

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 12
mpl.rcParams['text.usetex'] = False
mpl.rcParams['figure.figsize'] = (12.0, 9.0)
mpl.rcParams['legend.fancybox'] = True

# %%
dfeat, dtags = datasets.load_svmlight_file('boundMat.svmlight.txt', )
dfeat = dfeat.toarray()
X = preprocessing.scale(dfeat)

ddgs = np.array(loadtxt('boundRes.ddg.txt', skiprows=1, usecols=[3]))
y = ddgs>0

pdbs = loadtxt('boundMat.svmlight.txt', skiprows=1, usecols=[8], comments='$', dtype=np.str_)

# %%
classifier = svm.SVC(kernel='linear', probability=True, class_weight='auto')

# %%
classifier.fit(X[73:],y[73:])
# Out:
# SVC(C=1.0, cache_size=200, class_weight='auto', coef0=0.0, degree=3,
#   gamma=0.0, kernel='linear', probability=True, shrinking=True, tol=0.001,
#   verbose=False)

# %%
preds = classifier.predict_proba(X[:73])

surface_resnums = loadtxt('classifier1_full/SurfaceResidues/1AWR.bound.res', usecols=[1], dtype=int)
assert len(surface_resnums)==len(preds[:,1])

bfactors = defaultdict(float)
for num, b in zip(surface_resnums, preds[:,1]):
    bfactors[num] = b

# %%
prot = parsePDB('classifier1_full/results_Bwk/1AWR.results.pdb')
# Out:
# @> 1298 atoms and 1 coordinate set(s) were parsed in 0.02s.

# %%
samples = prot.select('chain A and ((resname GLY and name CA) or ((not resname GLY) and name CB))').select('resnum %s' % ' '.join(map(str, surface_resnums)))
print len(samples)
print samples.getResnums()
# Out:
# 73
# [  1  12  13  14  15  18  25  26  27  29  30  33  40  41  42  43  44  48
#   49  54  57  58  59  67  68  69  70  71  72  78  79  80  81  83  85  87
#   88  90  92  94 101 102 103 104 105 106 112 117 119 120 121 122 123 124
#  125 130 132 133 136 139 143 146 147 148 150 152 153 154 158 159 162 163
#  164]

# %%
def modifiedBetas(prot, resnums, bfactors):
    p = prot.copy()
    p.setBetas([0]*len(p))
    
    h = p.select('chain A and resnum %s' % ' '.join(map(str, resnums))).getHierView()
    for resnum, bfactor in zip(resnums, bfactors):
        res = h.getResidue('A', resnum)
        res.setBetas([bfactor]*len(res))
    
    return p

# %%
ag_preds = modifiedBetas(prot, surface_resnums, preds[:,1])
writePDB('1awr.preds.pdb', ag_preds)
# Out:
# '1awr.preds.pdb'

# %%
print zip(surface_resnums, preds[:,1])
# Out:
# [(1, 0.064474759122290601), (12, 0.050210331242187052), (13, 0.050977736692266497), (14, 0.047891813735557641), (15, 0.044336530632229414), (18, 0.06354554851956086), (25, 0.048625183569847845), (26, 0.06354554851956086), (27, 0.050210331242187052), (29, 0.059707407993956713), (30, 0.047891813735557641), (33, 0.06073239395031535), (40, 0.07230137042386979), (41, 0.29533579835002671), (42, 0.066479787371808707), (43, 0.055173824116278754), (44, 0.2966606424086784), (48, 0.30220098993924144), (49, 0.25800430069276276), (54, 0.37811870912753243), (57, 0.059546475854757086), (58, 0.048625183569847845), (59, 0.38165089569477884), (67, 0.06354554851956086), (68, 0.053239864607186195), (69, 0.047891813735557641), (70, 0.06354554851956086), (71, 0.41829591295555479), (72, 0.39872580569435484), (78, 0.066479787371808707), (79, 0.067448814390326559), (80, 0.32826458511277701), (81, 0.40311180024184079), (83, 0.047891813735557641), (85, 0.066479787371808707), (87, 0.068966545827864628), (88, 0.
# ...

# %%
cb_coords = samples.getCoords()
y = preds[:,1]
assert len(y)==cb_coords.shape[0]

# %%
binary_preds = classifier.predict(X[:73])
ag_binary = modifiedBetas(prot, surface_resnums, binary_preds)
writePDB('1awr.binary.pdb', ag_binary)
# Out:
# '1awr.binary.pdb'

# %%
positives = parsePDB('1awr.binary.pdb').select('sidechain and same residue as (name CA and chain A and beta>0)')
# Out:
# @> 1298 atoms and 1 coordinate set(s) were parsed in 0.01s.

# %%
N_CLUSTERS = 4
connectivity = kneighbors_graph(positives.getCoords(), 5)
ward = Ward(n_clusters=N_CLUSTERS, connectivity=connectivity)
ward.fit(positives.getCoords())
cluster_labels = ward.labels_

ag_clustered = modifiedBetas(prot, positives.getResnums(), N_CLUSTERS - cluster_labels)
writePDB('1awr.clustered.pdb', ag_clustered)
# Out:
# /home/assaff/local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py:111: UserWarning: the number of connected components of the connectivity matrix is 13 > 1. Completing it to avoid stopping the tree early.
#   % n_components)
# '1awr.clustered.pdb'

# %%
db_clust = DBSCAN(eps=6, min_samples=2, )
db_clust.fit(positives.getCoords())

cluster_labels = map(int, db_clust.labels_)
#db_clust.core_sample_indices_

# %%
prody.SETTINGS['auto_show']=False
showProtein(prot, A='grey', B='magenta', label='prot', lw=3)
s = positives.copy()
s.setTitle('positive')
s.setResnames(['CL%s_' % str(label) for label in cluster_labels])
cluster_colors = {
        'CL0_': 'Red',
        'CL1_': 'DarkOrange',
        'CL2_': 'Coral',
        'CL3_': 'Yellow',
        'CL4_': 'White',
        'CL-1_': 'Green',
        }
print cluster_colors
showProtein(s, hsize=10, label='positives', **cluster_colors)
pl.legend(loc='upper left')
pl.show()
# Out:
# {'CL1_': 'DarkOrange', 'CL0_': 'Red', 'CL4_': 'White', 'CL2_': 'Coral', 'CL3_': 'Yellow', 'CL-1_': 'Green'}

# %%
def planarity(coords):
    pca = decomposition.PCA()
    pca.fit(coords)
    return 1-pca.explained_variance_ratio_[-1]

# %%
def score_clusters(coords, cluster_labels):
    clusters = [coords[cluster_labels==i] for i in range(N_CLUSTERS)]
    planarities = np.array([planarity(cl_coords) for cl_coords in clusters])
    plana = planarities #preprocessing.scale(planarities)
    
    print plana
    sizes = np.array(map(len, clusters))
    print sizes
    
    scores = plana * sizes
    return scores
    #print len(coords), planarity,
    #return len(coords) * planarity

# %%
#
# Out:
# [ 0.36351247  0.39999282  0.36038175  0.35014872]
# [4 4 7 6]
# array([ 1.45404988,  1.59997127,  2.52267226,  2.10089231])

# %%
reg_results = zeros(shape=(len(y),))

cv = cross_validation.LeaveOneOut(len(y))
clf = RadiusNeighborsRegressor(radius=8.0, weights='distance', algorithm='kd_tree') #n_neighbors=3, 
for i, (train, test) in enumerate(cv):
    clf.fit(cb_coords[train],y[train])
    reg_results[i] = clf.predict(cb_coords[test])
    print reg_results[i], y[test]
# Out:
# 0.0601999578591 [ 0.06410531]
# 0.0483313199551 [ 0.0498142]
# 0.047844922692 [ 0.05058071]
# 0.0482755157335 [ 0.04749888]
# 0.0492928903158 [ 0.04395004]
# 0.0474988752289 [ 0.06317518]
# 0.0595446867161 [ 0.04823115]
# 0.0525677393871 [ 0.06317518]
# 0.0558890430336 [ 0.0498142]
# 0.055205610388 [ 0.06199693]
# 0.0629389657406 [ 0.04749888]
# 0.052547690266 [ 0.06035984]
# 0.143416141662 [ 0.07194306]
# 0.147958884551 [ 0.29646398]
# 0.171000423996 [ 0.06611261]
# 0.219457551773 [ 0.05477334]
# 0.137476804039 [ 0.29780026]
# 0.205452487378 [ 0.30338845]
# 0.161950943204 [ 0.25881289]
# 0.287725432433 [ 0.37988433]
# 0.113961824183 [ 0.05914479]
# 0.222119619484 [ 0.04823115]
# 0.0526224079289 [ 0.38344956]
# 0.0507026184379 [ 0.06317518]
# 0.199028864927 [ 0.05284068]
# 0.133554134227 [ 0.04749888]
# 0.236940817148 [ 0.06317518]
# 0.19520731717 [ 0.42042704]
# 0.177994056662 [ 0.40068226]
# 0.169310959786 [ 0.06611261]
# 0.248216501392 [ 0.06708288]
# 0.196966296682 [ 0.32956449]
# ...

# %%
writePDB('1awr.regression.pdb', modifiedBetas(prot, surface_resnums, reg_results))
# Out:
# '1awr.regression.pdb'

# %%
print clf.score(X_, y_)
preds = clf.predict(X_)
print scipy.stats.spearmanr(preds, y_)
#print scipy.stats.
# Out:
# 0.301956133313
# (0.50446851546941796, 9.8212853911609387e-85)

# %%
scipy.stats.pearsonr(preds, y_)
# Out:
# (0.55009119064358625, 1.5153819820840879e-103)
